# %%
def printCalendar(yy):

    month ={1:'January', 2:'February', 3:'March', 
            4:'April', 5:'May', 6:'June', 7:'July', 
            8:'August', 9:'September', 10:'October', 
            11:'November', 12:'December'} 
    f = open("calendar.txt", "w")
    f.write("+---------------------+ \n")
    for mm in range (1,13):

        # code below for calculation of odd days 
        day =(yy-1)% 400
        day = (day//100)*5 + ((day % 100) - (day % 100)//4) + ((day % 100)//4)*2
        day = day % 7


        nly =[31, 28, 31, 30, 31, 30, 
            31, 31, 30, 31, 30, 31] 
        ly =[31, 29, 31, 30, 31, 30, 
            31, 31, 30, 31, 30, 31] 
        s = 0

        if yy % 4 == 0: 
            for i in range(mm-1): 
                s+= ly[i] 
        else: 
            for i in range(mm-1): 
                s+= nly[i] 


        day += s % 7
        day = day % 7

        space ='' 
        space = space.rjust(2,' ') 

        
        # code below is to print the calendar

        f.write("     ")
        f.write(month[mm])
        f.write(" ")
        f.write(str(yy))
        f.write("\n")
        f.write("|")
        f.write("Su")
        f.write(" Mo")
        f.write(" Tu")
        f.write(" WE")
        f.write(" Th")
        f.write(" Fr")
        f.write(" Sa ")
        f.write("|")
        f.write("\n")

        if mm == 9 or mm == 4 or mm == 6 or mm == 11: 
            if day ==6:
                f.write("|")
                for i in range(7,(31+day)):
                    value = "{:02d}".format(i-day)
                    f.write(value)
                    f.write(" ")
                    if (i+1 )% 7 == 0:
                        f.write("|")
                        f.write("\n")
                        f.write("|")
            else:
                f.write("|")
                for i in range(32 + day):
                    if i<= day:
                        f.write("   ")
                    else:
                        value = "{:02d}".format(i-day)
                        f.write(value)
                        f.write(" ")
                        if (i+1 )% 7 == 0:
                            f.write("|")
                            f.write("\n")
                            f.write("|")

        elif mm == 2: 
            if yy % 4 == 0: 
                p = 30
            else: 
                p = 29

            if day ==6:
                f.write("|")
                for i in range(7,(32+day)):
                    value = "{:02d}".format(i-day)
                    f.write(value)
                    f.write(" ")
                    if (i+1 )% 7 == 0:
                        f.write("|")
                        f.write("\n")
                        f.write("|")
            else:
                f.write("|")
                for i in range(32 + day):
                    if i<= day:
                        f.write("   ")
                    else:
                        value = "{:02d}".format(i-day)
                        f.write(value)
                        f.write(" ")
                        if (i+1 )% 7 == 0:
                            f.write("|")
                            f.write("\n")
                            f.write("|")
        else:
            if day ==6:
                f.write("|")
                for i in range(7,(32+day)):
                    value = "{:02d}".format(i-day)
                    f.write(value)
                    f.write(" ")
                    if (i+1 )% 7 == 0:
                        f.write("|")
                        f.write("\n")
                        f.write("|")
            else:
                f.write("|")
                for i in range(32 + day):
                        if i<= day:
                            f.write("   ") 
                        else:
                            value = "{:02d}".format(i-day)
                            f.write(value)
                            f.write(" ")
                            if (i+1 )% 7 == 0:
                                f.write("|")
                                f.write("\n")
                                f.write("|")
        f.write("\n+---------------------+ \n")
    f.close()

    
print("Welcome To My calendar App")
printCalendar(int(input("Tell us the year here: ")))
print("Calendar has been saved in your in your system in the same directory")
print("Thanks for using us")
# Out:
# Welcome To My calendar App
# Tell us the year here: 2021
# Calendar has been saved in your in your system in the same directory
# Thanks for using us
